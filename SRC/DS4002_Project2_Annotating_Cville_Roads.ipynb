# %%
#!pip install fiftyone
import fiftyone as fo
import fiftyone.zoo as foz

# %%
# !pip install fiftyone labelbox

# %%
# %env FIFTYONE_LABELBOX_API_KEY='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..ND3BsTn-CNwws0SrrVmMGFF4NYF8ZqnIUggk7hDzxvk'
# Out:
# env: FIFTYONE_LABELBOX_API_KEY='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..ND3BsTn-CNwws0SrrVmMGFF4NYF8ZqnIUggk7hDzxvk'

# %%
dataset = fo.Dataset.from_dir(dataset_dir="/Users/treypallace/Desktop/cville_roads", dataset_type=fo.types.ImageDirectory)
# Out:
#  100% |███████████████████| 10/10 [22.1ms elapsed, 0s remaining, 453.0 samples/s]

# %%
session = fo.launch_app(dataset)
# Out:
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# body, html {
#   margin: 0;
#   padding: 0;
#   width: 100%;
# }
#
# #focontainer-4a5504fa-1349-4d98-8b35-4f7f6f81e28f {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-4a5504fa-1349-4d98-8b35-4f7f6f81e28f {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-4a5504fa-1349-4d98-8b35-4f7f6f81e28f:focus {
#   outline: none;
# }
# #fooverlay-4a5504fa-1349-4d98-8b35-4f7f6f81e28f {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
# ...

# %%
session.freeze()

# %%
anno_key = "annotation_run_2"

results = dataset.annotate(
    anno_key,
    backend="labelbox",
    label_field="detections",
    classes=["Pedestrian", "Truck", "Car","Cyclist","Van","Person Sitting"],
    label_type="detections",
    launch_editor=True,
)
# Out:
# Please enter your API key.
# You can avoid this in the future by setting your `FIFTYONE_LABELBOX_KEY` environment variable
# API key: ········
# Uploading media to Labelbox...
#  10 [8.7s elapsed, 1.2 samples/s]
# Passing a queue mode of batch is redundant and will soon no longer be supported.
# Upload complete
# Launching editor at 'https://editor.labelbox.com/?project=clo1m00gx0hbd07v7bdn79uuo'...

# %%
dataset.load_annotations(anno_key, cleanup=True)
# Out:
# ...
# ---------------------------------------------------------------------------
# InvalidQueryError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 dataset.load_annotations(anno_key, cleanup=True)
#
# File ~/miniconda3/lib/python3.10/site-packages/fiftyone/core/collections.py:8438, in SampleCollection.load_annotations(self, anno_key, dest_field, unexpected, cleanup, **kwargs)
#    8397 def load_annotations(
#    8398     self,
#    8399     anno_key,
#    (...)
#    8403     **kwargs,
#    8404 ):
#    8405     """Downloads the labels from the given annotation run from the
#    8406     annotation backend and merges them into this collection.
#    8407
#    (...)
#    8436         found, in which case a dict containing the extra labels is returned
#    8437     """
# -> 8438     return foua.load_annotations(
#    8439         self,
#    8440         anno_key,
#    8441         dest_field=dest_field,
#    8442         unexpected=unexpected,
# ...

# %%
session = fo.launch_app(dataset)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=True&subscription=c97e7980-6db4-4f69-86f7-11bbe3254e60"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
session.freeze()

# %%
# Out:
# {}

# %%
# The directory to which to write the exported dataset
export_dir = "/Users/treypallace/Desktop"

# The name of the sample field containing the label that you wish to export
# Used when exporting labeled datasets (e.g., classification or detection)
label_field = "detections"  # for example

# The type of dataset to export
# Any subclass of `fiftyone.types.Dataset` is supported
dataset_type = fo.types.YOLOv5Dataset  # for example

# Export the dataset
dataset.export(
    export_dir=export_dir,
    dataset_type=dataset_type,
    label_field=label_field,
)
# Out:
# Directory '/Users/treypallace/Desktop' already exists; export will be merged with existing files
#  100% |███████████████████| 10/10 [31.5ms elapsed, 0s remaining, 317.7 samples/s]
